# %%
import git

# URL of the GitHub repository
repo_url = 'https://github.com/PhonePe/pulse.git'

# Local directory where you want to clone the repository
local_directory = r'C:\Users\DELL\phone_pe_pulse'

# Clone the repository
git.Repo.clone_from(repo_url, local_directory)

# %%
import pandas as pd
import json
import os

# %%
path="C:\\Users\\DELL\\phone_pe_pulse\\data\\aggregated\\transaction\\country\\india\\state"   #path=r"C:\Users\DELL\phone_pe_pulse\data\aggregated\transaction\country\india\state"
Agg_state_list=os.listdir(path)
Agg_state_list

clm={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}


for state in Agg_state_list:
    state_path = os.path.join(path, state)
    if os.path.isdir(state_path):
        Agg_yr = os.listdir(state_path)
        for year in Agg_yr:
            yr_path = os.path.join(state_path, year)
            if os.path.isdir(yr_path):
                Agg_yr_list = os.listdir(yr_path)
                for quarter in Agg_yr_list:
                    quarter_path = os.path.join(yr_path, quarter)
                    Data=open(quarter_path,'r')
                    D=json.load(Data)
                    for z in D['data']['transactionData']:
                        Name=z['name']
                        count=z['paymentInstruments'][0]['count']
                        amount=z['paymentInstruments'][0]['amount']
                        clm['Transacion_type'].append(Name)
                        clm['Transacion_count'].append(count)
                        clm['Transacion_amount'].append(amount)
                        clm['State'].append(state)
                        clm['Year'].append(year)
                        clm['Quater'].append(int(quarter.strip('.json')))
#Succesfully created a dataframe
Agg_Trans=pd.DataFrame(clm)


Agg_Trans["States"] = Agg_Trans["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar islands')           
Agg_Trans["States"] = Agg_Trans["States"].str.replace('-'," ")
Agg_Trans["States"] = Agg_Trans["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu', 'Dadra and Nagar Haveli and Daman and Diu')
Agg_Trans["States"] = Agg_Trans["States"].str.title()

# %%
Agg_Trans
# Out:
#                           State  Year  Quater           Transacion_type  \
# 0     andaman-&-nicobar-islands  2018       1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018       1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018       1         Merchant payments
# 3     andaman-&-nicobar-islands  2018       1        Financial Services
# 4     andaman-&-nicobar-islands  2018       1                    Others
# ...                         ...   ...     ...                       ...
# 4489                west-bengal  2024       1         Merchant payments
# 4490                west-bengal  2024       1     Peer-to-peer payments
# 4491                west-bengal  2024       1  Recharge & bill payments
# 4492                west-bengal  2024       1        Financial Services
# 4493                west-bengal  2024       1                    Others
#
#       Transacion_count  Transacion_amount
# 0                 4200       1.845307e+06
# ...

# %%
path_1="C:\\Users\\DELL\\phone_pe_pulse\\data\\aggregated\\user\\country\\india\\state"  #path=r"C:\Users\DELL\phone_pe_pulse\data\aggregated\transaction\country\india\state"
Agg_state_list_user=os.listdir(path_1)
Agg_state_list_user

user_info={'State':[], 'Year':[],'Quater':[],'Transacion_brand':[], 'Transacion_count':[], 'Transacion_percentage':[]}


for state in Agg_state_list_user:
    state_path_user = os.path.join(path_1, state)
    if os.path.isdir(state_path_user):
        Agg_yr_user = os.listdir(state_path_user)
        for year in Agg_yr_user:
            yr_path_user = os.path.join(state_path_user, year)
            if os.path.isdir(yr_path_user):
                Agg_yr_list_user = os.listdir(yr_path_user)
                for q in Agg_yr_list_user:
                    q_p_u = os.path.join(yr_path_user, q)
                    Data=open(q_p_u,'r')
                    B=json.load(Data)
                    try:
                        for z in B['data']['usersByDevice']:
                            Name=z['brand']
                            count=z['count']
                            amount=z['percentage']
                            user_info['Transacion_brand'].append(Name)
                            user_info['Transacion_count'].append(count)
                            user_info['Transacion_percentage'].append(amount*100)
                            user_info['State'].append(state)
                            user_info['Year'].append(year)
                            user_info['Quater'].append(int(quarter.strip('.json')))
                    except:
                        pass
#Succesfully created a dataframe
Agg_user=pd.DataFrame(user_info)

# %%
Agg_user
# Out:
#                           State  Year  Quater Transacion_brand  \
# 0     andaman-&-nicobar-islands  2018       1           Xiaomi
# 1     andaman-&-nicobar-islands  2018       1          Samsung
# 2     andaman-&-nicobar-islands  2018       1             Vivo
# 3     andaman-&-nicobar-islands  2018       1             Oppo
# 4     andaman-&-nicobar-islands  2018       1          OnePlus
# ...                         ...   ...     ...              ...
# 6727                west-bengal  2022       1           Lenovo
# 6728                west-bengal  2022       1          Infinix
# 6729                west-bengal  2022       1             Asus
# 6730                west-bengal  2022       1            Apple
# 6731                west-bengal  2022       1           Others
#
#       Transacion_count  Transacion_percentage
# 0                 1665              24.703264
# 1                 1445              21.439169
# 2                  982              14.569733
# ...

# %%
path_2="C:\\Users\\DELL\\phone_pe_pulse\\data\\aggregated\\insurance\\country\\india\\state"  #path=r"C:\Users\DELL\phone_pe_pulse\data\aggregated\transaction\country\india\state"
state_insurance=os.listdir(path_2)
state_insurance

clm_1={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}


for state in state_insurance:
    state_path = os.path.join(path_2, state)
    if os.path.isdir(state_path):
        Agg_yr = os.listdir(state_path)
        for year in Agg_yr:
            yr_path = os.path.join(state_path, year)
            if os.path.isdir(yr_path):
                Agg_yr_list = os.listdir(yr_path)
                for quarter in Agg_yr_list:
                    quarter_path = os.path.join(yr_path, quarter)
                    Data=open(quarter_path,'r')
                    D=json.load(Data)
                    for z in D['data']['transactionData']:
                        Name=z['name']
                        count=z['paymentInstruments'][0]['count']
                        amount=z['paymentInstruments'][0]['amount']
                        clm_1['Transacion_type'].append(Name)
                        clm_1['Transacion_count'].append(count)
                        clm_1['Transacion_amount'].append(amount)
                        clm_1['State'].append(state)
                        clm_1['Year'].append(year)
                        clm_1['Quater'].append(int(quarter.strip('.json')))
#Succesfully created a dataframe
Agg_insurance=pd.DataFrame(clm_1)

# %%
Agg_insurance
# Out:
#                          State  Year  Quater Transacion_type  \
# 0    andaman-&-nicobar-islands  2020       2       Insurance
# 1    andaman-&-nicobar-islands  2020       3       Insurance
# 2    andaman-&-nicobar-islands  2020       4       Insurance
# 3    andaman-&-nicobar-islands  2021       1       Insurance
# 4    andaman-&-nicobar-islands  2021       2       Insurance
# ..                         ...   ...     ...             ...
# 569                west-bengal  2023       1       Insurance
# 570                west-bengal  2023       2       Insurance
# 571                west-bengal  2023       3       Insurance
# 572                west-bengal  2023       4       Insurance
# 573                west-bengal  2024       1       Insurance
#
#      Transacion_count  Transacion_amount
# 0                   6             1360.0
# 1                  41            15380.0
# 2                 124           157975.0
# 3                 225           244266.0
# ...

# %%
path_map="C:\\Users\\DELL\\phone_pe_pulse\\data\\map\\transaction\\hover\\country\\india\\state" #path=r"C:\Users\DELL\phone_pe_pulse\data\aggregated\transaction\country\india\state"
map_trans=os.listdir(path_map)
map_trans

clm_2={'State':[], 'Year':[],'Quater':[],'district':[], 'Transacion_count':[], 'Transacion_amount':[]}


for state in map_trans:
    state_path = os.path.join(path_map, state)
    if os.path.isdir(state_path):
        Agg_yr = os.listdir(state_path)
        for year in Agg_yr:
            yr_path = os.path.join(state_path, year)
            if os.path.isdir(yr_path):
                Agg_yr_list = os.listdir(yr_path)
                for quarter in Agg_yr_list:
                    quarter_path = os.path.join(yr_path, quarter)
                    Data=open(quarter_path,'r')
                    D=json.load(Data)
                    try:
                     for z in D['data']['hoverDataList']:
                        Name=z['name']
                        count=z['metric'][0]['count']
                        amount=z['metric'][0]['amount']
                        clm_2['district'].append(Name)
                        clm_2['Transacion_count'].append(count)
                        clm_2['Transacion_amount'].append(amount)
                        clm_2['State'].append(state)
                        clm_2['Year'].append(year)
                        clm_2['Quater'].append(int(quarter.strip('.json')))
                    except:
                        pass
#Succesfully created a dataframe
map_Trans=pd.DataFrame(clm_2)

# %%
map_Trans
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 18291                west-bengal  2024       1
# 18292                west-bengal  2024       1
# 18293                west-bengal  2024       1
# 18294                west-bengal  2024       1
# 18295                west-bengal  2024       1
#
#                                 district  Transacion_count  Transacion_amount
# 0      north and middle andaman district               442       9.316631e+05
# 1                 south andaman district              5688       1.256025e+07
# 2                      nicobars district               528       1.139849e+06
# 3      north and middle andaman district               825       1.317863e+06
# ...

# %%
path_map_1="C:\\Users\\DELL\\phone_pe_pulse\\data\\map\\user\\hover\\country\\india\\state" #path=r"C:\Users\DELL\phone_pe_pulse\data\aggregated\transaction\country\india\state"
map_user=os.listdir(path_map_1)
map_user

clm_map={'State':[], 'Year':[],'Quater':[],'district':[], 'registeredUsers':[]}


for state in map_user:
    state_path = os.path.join(path_map_1, state)
    if os.path.isdir(state_path):
        Agg_yr = os.listdir(state_path)
        for year in Agg_yr:
            yr_path = os.path.join(state_path, year)
            if os.path.isdir(yr_path):
                Agg_yr_list = os.listdir(yr_path)
                for quarter in Agg_yr_list:
                    quarter_path = os.path.join(yr_path, quarter)
                    Data=open(quarter_path,'r')
                    D=json.load(Data)
                    try:
                     for z in D['data']['hoverData'].items():
                        Name=z[0]
                        count=z[1]['registeredUsers']
                        
                        clm_map['district'].append(Name)
                        clm_map['registeredUsers'].append(count)
                        
                        clm_map['State'].append(state)
                        clm_map['Year'].append(year)
                        clm_map['Quater'].append(int(quarter.strip('.json')))
                    except:
                        pass
#Succesfully created a dataframe
map_user=pd.DataFrame(clm_map)

# %%
map_user
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 18295                west-bengal  2024       1
# 18296                west-bengal  2024       1
# 18297                west-bengal  2024       1
# 18298                west-bengal  2024       1
# 18299                west-bengal  2024       1
#
#                                 district  registeredUsers
# 0      north and middle andaman district              632
# 1                 south andaman district             5846
# 2                      nicobars district              262
# 3      north and middle andaman district              911
# 4                 south andaman district             8143
# ...

# %%
import os
import json

path_map_1 = "C:\\Users\\DELL\\phone_pe_pulse\\data\\map\\user\\hover\\country\\india\\state"
map_user = os.listdir(path_map_1)

clm_map = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'District': [],
    'RegisteredUsers': [],
    'AppOpens': []
}

for state in map_user:
    state_path = os.path.join(path_map_1, state)
    if os.path.isdir(state_path):
        Agg_yr = os.listdir(state_path)
        for year in Agg_yr:
            yr_path = os.path.join(state_path, year)
            if os.path.isdir(yr_path):
                Agg_yr_list = os.listdir(yr_path)
                for quarter in Agg_yr_list:
                    quarter_path = os.path.join(yr_path, quarter)
                    try:
                        with open(quarter_path, 'r') as json_file:
                            data = json.load(json_file)
                            hover_data = data.get('data', {}).get('hoverData', {})
                            for district, district_data in hover_data.items():
                                Name = district
                                count = district_data.get('registeredUsers', 0)
                                amount = district_data.get('appOpens', 0)
                                clm_map['District'].append(Name)
                                clm_map['RegisteredUsers'].append(count)
                                clm_map['AppOpens'].append(amount)
                                clm_map['State'].append(state)
                                clm_map['Year'].append(year)
                                clm_map['Quarter'].append(int(quarter.strip('.json')))
                    except Exception as e:
                        print(f"Error processing file {quarter_path}: {e}")

# Successfully created a dataframe
map_user = pd.DataFrame(clm_map)

# %%
map_user
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 18295                west-bengal  2024        1
# 18296                west-bengal  2024        1
# 18297                west-bengal  2024        1
# 18298                west-bengal  2024        1
# 18299                west-bengal  2024        1
#
#                                 District  RegisteredUsers  AppOpens
# 0      north and middle andaman district              632         0
# 1                 south andaman district             5846         0
# 2                      nicobars district              262         0
# 3      north and middle andaman district              911         0
# ...

# %%
path_top= "C:\\Users\\DELL\\phone_pe_pulse\\data\\top\\transaction\\country\\india\\state" #path=r"C:\Users\DELL\phone_pe_pulse\data\aggregated\transaction\country\india\state"
top_trans=os.listdir(path_top)
top_trans

clm_3={'State':[], 'Year':[],'Quater':[],'pincodes':[], 'Transacion_count':[], 'Transacion_amount':[]}


for state in top_trans:
    state_path = os.path.join(path_top, state)
    if os.path.isdir(state_path):
        Agg_yr = os.listdir(state_path)
        for year in Agg_yr:
            yr_path = os.path.join(state_path, year)
            if os.path.isdir(yr_path):
                Agg_yr_list = os.listdir(yr_path)
                for quarter in Agg_yr_list:
                    quarter_path = os.path.join(yr_path, quarter)
                    Data=open(quarter_path,'r')
                    D=json.load(Data)
                    try:
                     for z in D['data']['pincodes']:
                        Name=z['entityName']
                        count=z['metric']['count']
                        amount=z['metric']['amount']
                        clm_3['pincodes'].append(Name)
                        clm_3['Transacion_count'].append(count)
                        clm_3['Transacion_amount'].append(amount)
                        clm_3['State'].append(state)
                        clm_3['Year'].append(year)
                        clm_3['Quater'].append(int(quarter.strip('.json')))
                    except:
                        pass
#Succesfully created a dataframe
top_Trans=pd.DataFrame(clm_3)

# %%
top_Trans
# Out:
#                           State  Year  Quater pincodes  Transacion_count  \
# 0     andaman-&-nicobar-islands  2018       1   744101              1622
# 1     andaman-&-nicobar-islands  2018       1   744103              1223
# 2     andaman-&-nicobar-islands  2018       1   744102               969
# 3     andaman-&-nicobar-islands  2018       1   744105               685
# 4     andaman-&-nicobar-islands  2018       1   744104               340
# ...                         ...   ...     ...      ...               ...
# 8919                west-bengal  2024       1   732125           4490229
# 8920                west-bengal  2024       1   700006           4358390
# 8921                west-bengal  2024       1   700001           4321119
# 8922                west-bengal  2024       1   732201           4265219
# 8923                west-bengal  2024       1   742202           3985791
#
#       Transacion_amount
# 0          2.769298e+06
# 1          2.238042e+06
# ...

# %%
path_top_1= "C:\\Users\\DELL\\phone_pe_pulse\\data\\top\\user\\country\\india\\state" #path=r"C:\Users\DELL\phone_pe_pulse\data\aggregated\transaction\country\india\state"
top_user=os.listdir(path_top)
top_user

clm_4={'State':[], 'Year':[],'Quater':[],'pincodes':[], 'registeredUsers':[]}


for state in top_user:
    state_path = os.path.join(path_top_1, state)
    if os.path.isdir(state_path):
        Agg_yr = os.listdir(state_path)
        for year in Agg_yr:
            yr_path = os.path.join(state_path, year)
            if os.path.isdir(yr_path):
                Agg_yr_list = os.listdir(yr_path)
                for quarter in Agg_yr_list:
                    quarter_path = os.path.join(yr_path, quarter)
                    Data=open(quarter_path,'r')
                    D=json.load(Data)
                    try:
                     for z in D['data']['pincodes']:
                        Name=z['name']
                        count=z['registeredUsers']
                       
                        clm_4['pincodes'].append(Name)
                        clm_4['registeredUsers'].append(count)
                        
                        clm_4['State'].append(state)
                        clm_4['Year'].append(year)
                        clm_4['Quater'].append(int(quarter.strip('.json')))
                    except:
                        pass
#Succesfully created a dataframe
top_user=pd.DataFrame(clm_4)

# %%
top_user
# Out:
#                           State  Year  Quater pincodes  registeredUsers
# 0     andaman-&-nicobar-islands  2018       1   744103             1608
# 1     andaman-&-nicobar-islands  2018       1   744101             1108
# 2     andaman-&-nicobar-islands  2018       1   744105             1075
# 3     andaman-&-nicobar-islands  2018       1   744102             1006
# 4     andaman-&-nicobar-islands  2018       1   744104              272
# ...                         ...   ...     ...      ...              ...
# 8920                west-bengal  2024       1   700015           131676
# 8921                west-bengal  2024       1   742304           127917
# 8922                west-bengal  2024       1   721101           127891
# 8923                west-bengal  2024       1   700150           123919
# 8924                west-bengal  2024       1   700091           122985
#
# [8925 rows x 5 columns]

# %%
path_top= "C:\\Users\\DELL\\phone_pe_pulse\\data\\top\\insurance\\country\\india\\state" #path=r"C:\Users\DELL\phone_pe_pulse\data\aggregated\transaction\country\india\state"
top_insurance=os.listdir(path_top)
top_insurance

clm_insu={'State':[], 'Year':[],'Quater':[],'pincodes':[], 'Transacion_count':[], 'Transacion_amount':[]}


for state in top_insurance:
    state_path = os.path.join(path_top, state)
    if os.path.isdir(state_path):
        Agg_yr = os.listdir(state_path)
        for year in Agg_yr:
            yr_path = os.path.join(state_path, year)
            if os.path.isdir(yr_path):
                Agg_yr_list = os.listdir(yr_path)
                for quarter in Agg_yr_list:
                    quarter_path = os.path.join(yr_path, quarter)
                    Data=open(quarter_path,'r')
                    D=json.load(Data)
                    try:
                     for z in D['data']['pincodes']:
                        Name=z['entityName']
                        count=z['metric']['count']
                        amount=z['metric']['amount']
                        clm_insu['pincodes'].append(Name)
                        clm_insu['Transacion_count'].append(count)
                        clm_insu['Transacion_amount'].append(amount)
                        clm_insu['State'].append(state)
                        clm_insu['Year'].append(year)
                        clm_insu['Quater'].append(int(quarter.strip('.json')))
                    except:
                        pass
#Succesfully created a dataframe
top_insu=pd.DataFrame(clm_insu)

# %%
top_insu
# Out:
#                           State  Year  Quater pincodes  Transacion_count  \
# 0     andaman-&-nicobar-islands  2020       2   744301                 3
# 1     andaman-&-nicobar-islands  2020       2   744104                 2
# 2     andaman-&-nicobar-islands  2020       2   744101                 1
# 3     andaman-&-nicobar-islands  2020       3   744112                 9
# 4     andaman-&-nicobar-islands  2020       3   744105                 7
# ...                         ...   ...     ...      ...               ...
# 5596                west-bengal  2024       1   700039               563
# 5597                west-bengal  2024       1   700015               558
# 5598                west-bengal  2024       1   700006               516
# 5599                west-bengal  2024       1   721301               507
# 5600                west-bengal  2024       1   700091               503
#
#       Transacion_amount
# 0                 565.0
# 1                 513.0
# ...

# %%
path_map="C:\\Users\\DELL\\phone_pe_pulse\\data\\map\\insurance\\hover\\country\\india\\state" #path=r"C:\Users\DELL\phone_pe_pulse\data\aggregated\transaction\country\india\state"
map_insu=os.listdir(path_map)
map_insu

clm_insu={'State':[], 'Year':[],'Quater':[],'district':[], 'Transacion_count':[], 'Transacion_amount':[]}


for state in map_insu:
    state_path = os.path.join(path_map, state)
    if os.path.isdir(state_path):
        Agg_yr = os.listdir(state_path)
        for year in Agg_yr:
            yr_path = os.path.join(state_path, year)
            if os.path.isdir(yr_path):
                Agg_yr_list = os.listdir(yr_path)
                for quarter in Agg_yr_list:
                    quarter_path = os.path.join(yr_path, quarter)
                    Data=open(quarter_path,'r')
                    D=json.load(Data)
                    try:
                     for z in D['data']['hoverDataList']:
                        Name=z['name']
                        count=z['metric'][0]['count']
                        amount=z['metric'][0]['amount']
                        clm_insu['district'].append(Name)
                        clm_insu['Transacion_count'].append(count)
                        clm_insu['Transacion_amount'].append(amount)
                        clm_insu['State'].append(state)
                        clm_insu['Year'].append(year)
                        clm_insu['Quater'].append(int(quarter.strip('.json')))
                    except:
                        pass
#Succesfully created a dataframe
map_insurance=pd.DataFrame(clm_insu)

# %%
map_insurance
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2020       2
# 1      andaman-&-nicobar-islands  2020       2
# 2      andaman-&-nicobar-islands  2020       3
# 3      andaman-&-nicobar-islands  2020       3
# 4      andaman-&-nicobar-islands  2020       3
# ...                          ...   ...     ...
# 11554                west-bengal  2024       1
# 11555                west-bengal  2024       1
# 11556                west-bengal  2024       1
# 11557                west-bengal  2024       1
# 11558                west-bengal  2024       1
#
#                                 district  Transacion_count  Transacion_amount
# 0                 south andaman district                 3              795.0
# 1                      nicobars district                 3              565.0
# 2      north and middle andaman district                 1              281.0
# 3                 south andaman district                35            13651.0
# ...

# %%
import pymysql

# Connect to MySQL
mydb = pymysql.connect(
    host="localhost",
    user="root",
    password="!QAZ2wsx#EDC",
    database="phonepe_pulse"
)

# Create a cursor object
cursor = mydb.cursor()

# Assuming you have dataframes Agg_Trans, Agg_user, etc.

# Export dataframes to MySQL tables using pymysql
# Iterate over each row in Agg_Trans dataframe and insert into 'aggregate_trans' table
for index, row in Agg_Trans.iterrows():
    sql = "INSERT INTO aggregate_trans (STATE, YEAR, QUARTER, TRANSACTION_TYPE, TRANSACTION_COUNT, TRANSACTION_AMOUNT) VALUES (%s, %s, %s, %s, %s, %s)"
    values = (row['State'], row['Year'], row['Quater'], row['Transacion_type'], row['Transacion_count'], row['Transacion_amount'])
    cursor.execute(sql, values)

# Commit the transaction
mydb.commit()

# Repeat the same process for other dataframes   '':[], '':[], '':[]}


# Close MySQL connection
mydb.close()

print("Data exported successfully to MySQL database.")
# Out:
# Data exported successfully to MySQL database.

# %%
import pymysql

# Connect to MySQL
mydb = pymysql.connect(
    host="localhost",
    user="root",
    password="!QAZ2wsx#EDC",
    database="phonepe_pulse"
)

# Create a cursor object
cursor = mydb.cursor()

# Assuming you have dataframes Agg_Trans, Agg_user, etc.

# Export dataframes to MySQL tables using pymysql
# Iterate over each row in Agg_Trans dataframe and insert into 'aggregate_user' table
for index, row in Agg_user.iterrows():
    sql = "INSERT INTO aggregate_user (STATE, YEAR, QUARTER, TRANSACTION_BRAND, TRANSACTION_COUNT, TRANSACTION_PERCENTAGE) VALUES (%s, %s, %s, %s, %s, %s)"
    values = (row['State'], row['Year'], row['Quater'], row['Transacion_brand'], row['Transacion_count'], row['Transacion_percentage'])
    cursor.execute(sql, values)

# Commit the transaction
mydb.commit()

# Repeat the same process for other dataframes   STATE VARCHAR(50), YEAR INT, QUARTER INT,  VARCHAR(50), INT, INT)")


# Close MySQL connection
mydb.close()

print("Data exported successfully to MySQL database.")
# Out:
# Data exported successfully to MySQL database.

# %%
import pymysql

# Connect to MySQL
mydb = pymysql.connect(
    host="localhost",
    user="root",
    password="!QAZ2wsx#EDC",
    database="phonepe_pulse"
)

# Create a cursor object
cursor = mydb.cursor()

# Assuming you have dataframes Agg_Trans, Agg_user, etc.

# Export dataframes to MySQL tables using pymysql
# Iterate over each row in Agg_Trans dataframe and insert into 'aggregate_insu' table
for index, row in Agg_insurance.iterrows():
    sql = "INSERT INTO aggregate_insu (STATE, YEAR, QUARTER, TRANSACTION_TYPE, TRANSACTION_COUNT, TRANSACTION_AMOUNT) VALUES (%s, %s, %s, %s, %s, %s)"
    values = (row['State'], row['Year'], row['Quater'], row['Transacion_type'], row['Transacion_count'], row['Transacion_amount'])
    cursor.execute(sql, values)

# Commit the transaction
mydb.commit()

# Repeat the same process for other dataframes   '':[], '':[], '':[]}


# Close MySQL connection
mydb.close()

print("Data exported successfully to MySQL database.")
# Out:
# Data exported successfully to MySQL database.

# %%
import pymysql

# Connect to MySQL
mydb = pymysql.connect(
    host="localhost",
    user="root",
    password="!QAZ2wsx#EDC",
    database="phonepe_pulse"
)

# Create a cursor object
cursor = mydb.cursor()

# Assuming you have dataframes Agg_Trans, Agg_user, etc.

# Export dataframes to MySQL tables using pymysql
# Iterate over each row in Agg_Trans dataframe and insert into 'map_insu' table
for index, row in map_insurance.iterrows():
    sql = "INSERT INTO map_insu (STATE, YEAR, QUARTER, DISTRICT, TRANSACTION_COUNT, TRANSACTION_AMOUNT) VALUES (%s, %s, %s, %s, %s, %s)"
    values = (row['State'], row['Year'], row['Quater'], row['district'], row['Transacion_count'], row['Transacion_amount'])
    cursor.execute(sql, values)

# Commit the transaction
mydb.commit()

# Repeat the same process for other dataframes   ':[], 'Transacion_count':[], 'T


# Close MySQL connection
mydb.close()

print("Data exported successfully to MySQL database.")
# Out:
# Data exported successfully to MySQL database.

# %%
import pymysql

# Connect to MySQL
mydb = pymysql.connect(
    host="localhost",
    user="root",
    password="!QAZ2wsx#EDC",
    database="phonepe_pulse"
)

# Create a cursor object
cursor = mydb.cursor()

# Assuming you have dataframes Agg_Trans, Agg_user, etc.

# Export dataframes to MySQL tables using pymysql
# Iterate over each row in Agg_Trans dataframe and insert into 'map_Trans' table
for index, row in map_Trans.iterrows():
    sql = "INSERT INTO map_trans (STATE, YEAR, QUARTER, DISTRICT, TRANSACTION_COUNT, TRANSACTION_AMOUNT) VALUES (%s, %s, %s, %s, %s, %s)"
    values = (row['State'], row['Year'], row['Quater'], row['district'], row['Transacion_count'], row['Transacion_amount'])
    cursor.execute(sql, values)

# Commit the transaction
mydb.commit()

# Repeat the same process for other dataframes   ':[], 'Transacion_count':[], 'T


# Close MySQL connection
mydb.close()

print("Data exported successfully to MySQL database.")
# Out:
# Data exported successfully to MySQL database.

# %%
import pymysql

# Connect to MySQL
mydb = pymysql.connect(
    host="localhost",
    user="root",
    password="!QAZ2wsx#EDC",
    database="phonepe_pulse"
)

# Create a cursor object
cursor = mydb.cursor()

# Assuming you have dataframes map_user, etc.

# Export dataframes to MySQL tables using pymysql
# Iterate over each row in Agg_Trans dataframe and insert into 'map_user' table
for index, row in map_user.iterrows():
    sql = "INSERT INTO map_user (STATE, YEAR, QUARTER, DISTRICT, REGISTERED_USERS, APP_OPENS ) VALUES (%s, %s, %s, %s, %s, %s)"
    values = (row['State'], row['Year'], row['Quarter'], row['District'], row['RegisteredUsers'], row['AppOpens'])
    cursor.execute(sql, values)

# Commit the transactionREGISTERED_USERS INT, APP_OPENS INT)
mydb.commit()

# Repeat the same process for other dataframes  


# Close MySQL connection
mydb.close()

print("Data exported successfully to MySQL database.")
# Out:
# Data exported successfully to MySQL database.

# %%
import pymysql

# Connect to MySQL
mydb = pymysql.connect(
    host="localhost",
    user="root",
    password="!QAZ2wsx#EDC",
    database="phonepe_pulse"
)

# Create a cursor object
cursor = mydb.cursor()

# Assuming you have dataframes Agg_Trans, Agg_user, etc.

# Export dataframes to MySQL tables using pymysql
# Iterate over each row in top_trans dataframe and insert into 'top_insu' table
for index, row in top_Trans.iterrows():
    sql = "INSERT INTO top_trans (STATE, YEAR, QUARTER, PINCODES, TRANSACTION_COUNT, TRANSACTION_AMOUNT) VALUES (%s, %s, %s, %s, %s, %s)"
    values = (row['State'], row['Year'], row['Quater'], row['pincodes'], row['Transacion_count'], row['Transacion_amount'])
    cursor.execute(sql, values)

# Commit the transaction
mydb.commit()

# Repeat the same process for other dataframes   ':[], 'Transacion_count':[], 'T'pincodes':[], 'Transacion_count':[], 'Transacion_amount':[]}


# Close MySQL connection
mydb.close()

print("Data exported successfully to MySQL database.")
# Out:
# Data exported successfully to MySQL database.

# %%
import pymysql

# Connect to MySQL
mydb = pymysql.connect(
    host="localhost",
    user="root",
    password="!QAZ2wsx#EDC",
    database="phonepe_pulse"
)

# Create a cursor object
cursor = mydb.cursor()

# Assuming you have dataframes Agg_Trans, Agg_user, etc.

# Export dataframes to MySQL tables using pymysql
# Iterate over each row in top_trans dataframe and insert into 'top_insu' table
for index, row in top_insu.iterrows():
    sql = "INSERT INTO top_insu (STATE, YEAR, QUARTER, PINCODES, TRANSACTION_COUNT, TRANSACTION_AMOUNT) VALUES (%s, %s, %s, %s, %s, %s)"
    values = (row['State'], row['Year'], row['Quater'], row['pincodes'], row['Transacion_count'], row['Transacion_amount'])
    cursor.execute(sql, values)

# Commit the transaction
mydb.commit()

# Repeat the same process for other dataframes   ':[], 'Transacion_count':[], 'T'pincodes':[], 'Transacion_count':[], 'Transacion_amount':[]}


# Close MySQL connection
mydb.close()

print("Data exported successfully to MySQL database.")
# Out:
# Data exported successfully to MySQL database.

# %%
import pymysql

# Connect to MySQL
mydb = pymysql.connect(
    host="localhost",
    user="root",
    password="!QAZ2wsx#EDC",
    database="phonepe_pulse"
)

# Create a cursor object
cursor = mydb.cursor()

# Assuming you have dataframes Agg_Trans, Agg_user, etc.

# Export dataframes to MySQL tables using pymysql
# Iterate over each row in top_trans dataframe and insert into 'top_insu' table
for index, row in top_user.iterrows():
    sql = "INSERT INTO top_user (STATE, YEAR, QUARTER, PINCODES, REGISTERED_USERS) VALUES (%s, %s, %s, %s, %s)"
    values = (row['State'], row['Year'], row['Quater'], row['pincodes'], row['registeredUsers'])
    cursor.execute(sql, values)

# Commit the transaction
mydb.commit()

# Repeat the same process for other dataframes   ':[], 'Transacion_count':[], 'T'pincodes':[], 'Transacion_count':[], 'Transacion_amount':[]}


# Close MySQL connection
mydb.close()

print("Data exported successfully to MySQL database.")
# Out:
# Data exported successfully to MySQL database.
